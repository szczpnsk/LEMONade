# %% [markdown]
# Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# Importing datasets

# %%
#Loading the TAS dataset
file_path = '/content/TAS.csv'
df_TAS = pd.read_csv(file_path, delimiter='\t', quotechar='"', header=0)

print(df_TAS.head())
# Out:
#   ,"TAS_Identification","TAS_Describing","TAS_ExternalThinking","TAS_OverallScore"
# 0                     sub-032311,"23","19","17","59"
# 1                     sub-032309,"14","20","19","53"
# 2                      sub-032382,"12","18","9","39"
# 3                     sub-032302,"18","14","13","45"
# 4                     sub-032315,"17","15","19","51"

# %%
split_columns_TAS = df_TAS[',TAS_Identification,TAS_Describing,TAS_ExternalThinking,TAS_OverallScore'].str.split(",", expand=True)

# %%
split_columns_TAS.head()
# Out:
#             0     1     2     3     4
# 0  sub-032311  "23"  "19"  "17"  "59"
# 1  sub-032309  "14"  "20"  "19"  "53"
# 2  sub-032382  "12"  "18"   "9"  "39"
# 3  sub-032302  "18"  "14"  "13"  "45"
# 4  sub-032315  "17"  "15"  "19"  "51"

# %%
df_TAS.head()
# Out:
#   ,TAS_Identification,TAS_Describing,TAS_ExternalThinking,TAS_OverallScore
# 0                     sub-032311,"23","19","17","59"
# 1                     sub-032309,"14","20","19","53"
# 2                      sub-032382,"12","18","9","39"
# 3                     sub-032302,"18","14","13","45"
# 4                     sub-032315,"17","15","19","51"

# %%
TAS_renamed = split_columns_TAS.rename(columns={
    0: "Participant",
    1: "Identification",
    2: "Describing",
    3: "ExternalThinking",
    4: "OverallScore"
})

# %%
TAS_renamed.head()
# Out:
#   Participant  Identification  Describing  ExternalThinking  OverallScore
# 0  sub-032311              23          19                17            59
# 1  sub-032309              14          20                19            53
# 2  sub-032382              12          18                 9            39
# 3  sub-032302              18          14                13            45
# 4  sub-032315              17          15                19            51

# %%
#Getting rid of quotations marks in the data
TAS_renamed['Identification'] = TAS_renamed['Identification'].str.strip('"').astype(int)
TAS_renamed['Describing'] = TAS_renamed['Describing'].str.strip('"').astype(int)
TAS_renamed['ExternalThinking'] = TAS_renamed['ExternalThinking'].str.strip('"').astype(int)
TAS_renamed['OverallScore'] = TAS_renamed['OverallScore'].str.strip('"').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-83f2fe01f030> in <cell line: 0>()
#       1 # Use a list to select multiple columns
# ----> 2 TAS_renamed['Identification'] = TAS_renamed['Identification'].str.strip('"').astype(int)
#       3 TAS_renamed['Describing'] = TAS_renamed['Describing'].str.strip('"').astype(int)
#       4 TAS_renamed['ExternalThinking'] = TAS_renamed['ExternalThinking'].str.strip('"').astype(int)
#       5 #TAS_renamed['OverallScore'] = TAS_renamed['OverallScore'].str.strip('"').astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     189         from pandas.core.arrays.string_ import StringDtype
#     190
# --> 191         self._inferred_dtype = self._validate(data)
#     192         self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     243
#     244         if inferred_dtype not in allowed_types:
# --> 245             raise AttributeError("Can only use .str accessor with string values!")
#     246         return inferred_dtype
#     247
#
# AttributeError: Can only use .str accessor with string values!

# %%
#Loading the STAXI dataset
file_path2 = '/content/STAXI.csv'
df_STAXI = pd.read_csv(file_path2, delimiter='\t', quotechar='"', header=0)

print(df_STAXI.head())
# Out:
#   ,"STAXI_State_Anger","STAXI_Trait_Anger","STAXI_TAT","STAXI_TAR","STAXI_AI","STAXI_AO","STAXI_AC"
# 0        sub-032311,"13","19","7","12","22","9","24"
# 1        sub-032309,"10","17","8","9","12","11","21"
# 2       sub-032382,"31","22","9","13","24","11","28"
# 3        sub-032302,"13","12","5","7","15","11","24"
# 4         sub-032315,"11","15","7","8","10","9","24"

# %%
split_columns_STAXI = df_STAXI[',STAXI_State_Anger,STAXI_Trait_Anger,STAXI_TAT,STAXI_TAR,STAXI_AI,STAXI_AO,STAXI_AC'].str.split(",", expand=True)

# %%
split_columns_STAXI.head()
# Out:
#             0     1     2    3     4     5     6     7
# 0  sub-032311  "13"  "19"  "7"  "12"  "22"   "9"  "24"
# 1  sub-032309  "10"  "17"  "8"   "9"  "12"  "11"  "21"
# 2  sub-032382  "31"  "22"  "9"  "13"  "24"  "11"  "28"
# 3  sub-032302  "13"  "12"  "5"   "7"  "15"  "11"  "24"
# 4  sub-032315  "11"  "15"  "7"   "8"  "10"   "9"  "24"

# %%
#Renaming the column that interests us
STAXI_renamed = split_columns_STAXI.rename(columns={
    7 : "Control"
})

# %%
STAXI_renamed['Control'] = STAXI_renamed['Control'].str.strip('"').astype(int)

# %%
STAXI_renamed.head()
# Out:
#             0     1     2    3     4     5     6  Control
# 0  sub-032311  "13"  "19"  "7"  "12"  "22"   "9"       24
# 1  sub-032309  "10"  "17"  "8"   "9"  "12"  "11"       21
# 2  sub-032382  "31"  "22"  "9"  "13"  "24"  "11"       28
# 3  sub-032302  "13"  "12"  "5"   "7"  "15"  "11"       24
# 4  sub-032315  "11"  "15"  "7"   "8"  "10"   "9"       24

# %%
STAXI_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0        221 non-null    object
#  1   1        221 non-null    object
#  2   2        221 non-null    object
#  3   3        221 non-null    object
#  4   4        221 non-null    object
#  5   5        221 non-null    object
#  6   6        221 non-null    object
#  7   Control  221 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 13.9+ KB

# %%
print(df_TAS.columns)
# Out:
# Index([',TAS_Identification,TAS_Describing,TAS_ExternalThinking,TAS_OverallScore'], dtype='object')

# %%
df_TAS.rename(columns={
    "TAS_Identification": "Identification",
    "TAS_Describing": "Describing",
    "TAS_OverallScore": "OverallScore"
}, inplace=True)

# %%
df_STAXI.columns
# Out:
# Index([',STAXI_State_Anger,STAXI_Trait_Anger,STAXI_TAT,STAXI_TAR,STAXI_AI,STAXI_AO,STAXI_AC'], dtype='object')

# %%
df_STAXI = df_STAXI.rename(columns={
    "STAXI_AC": "Control"
})

# %%
TAS_reduced = TAS_renamed[['Participant', 'Identification', 'Describing', 'OverallScore']]

# %%
TAS_reduced.head()
# Out:
#   Participant  Identification  Describing  OverallScore
# 0  sub-032311              23          19            59
# 1  sub-032309              14          20            53
# 2  sub-032382              12          18            39
# 3  sub-032302              18          14            45
# 4  sub-032315              17          15            51

# %%
STAXI_reduced = STAXI_renamed[['Control']]

# %%
#Merging the two datasets
concat_df = pd.concat([TAS_reduced, STAXI_reduced], axis=1)

# %%
concat_df.head()
# Out:
#   Participant  Identification  Describing  OverallScore  Control
# 0  sub-032311              23          19            59       24
# 1  sub-032309              14          20            53       21
# 2  sub-032382              12          18            39       28
# 3  sub-032302              18          14            45       24
# 4  sub-032315              17          15            51       24
